# %%
import pandas as pd

data = pd.read_csv("data.csv")
data
# Out:
#            time           bh        fuzzy      fuzzy c
# 0    1696093200  3000.000000  3000.000000  3000.000000
# 1    1696204800  2924.533106          NaN          NaN
# 2    1696291200  2913.877081          NaN          NaN
# 3    1696377600  2920.056738          NaN          NaN
# 4    1696464000  2874.005831          NaN          NaN
# ..          ...          ...          ...          ...
# 142  1708387200  5230.851733  4174.992581  3980.834989
# 143  1708473600  5301.909623  4242.990137  4007.059567
# 144  1708560000  5299.470396  4274.845156  4019.282716
# 145  1708646400  5219.133999          NaN          NaN
# 146  1708732800  5317.580333  4446.774620  4095.682459
#
# [147 rows x 4 columns]

# %%
time_column = pd.to_datetime(data['time'], unit='s')
bh_column = data['bh']
fuzzy_column = data['fuzzy'].interpolate()
fuzzy_c_column = data['fuzzy c'].interpolate()

fig = go.Figure()
fig.add_trace(go.Scatter(x=time_column, y=bh_column, mode='lines', name='bh'))
fig.add_trace(go.Scatter(x=time_column, y=fuzzy_column, mode='lines', name='fuzzy'))
fig.add_trace(go.Scatter(x=time_column, y=fuzzy_c_column, mode='lines', name='fuzzy c'))
fig.update_layout(
    xaxis=dict(title='Time'),
    yaxis=dict(title='USD $'),
)

fig.show()

# %%
data = pd.read_csv("data_stock.csv")
data
# Out:
#           time           bh        fuzzy      fuzzy c
# 0   1696093200  3000.000000  3000.000000  3000.000000
# 1   1696291200  2993.476035          NaN          NaN
# 2   1696377600  2966.472525          NaN          NaN
# 3   1696464000  3010.440796          NaN          NaN
# 4   1696550400  3014.721761          NaN          NaN
# ..         ...          ...          ...          ...
# 95  1708041600  3409.533047  3179.777238  3120.669418
# 96  1708387200  3368.968702          NaN          NaN
# 97  1708473600  3350.873156          NaN          NaN
# 98  1708560000  3389.837150          NaN          NaN
# 99  1708646400  3402.057064  3248.614044  3193.490259
#
# [100 rows x 4 columns]

# %%
time_column = pd.to_datetime(data['time'], unit='s')
bh_column = data['bh']
fuzzy_column = data['fuzzy'].interpolate()
fuzzy_c_column = data['fuzzy c'].interpolate()

fig = go.Figure()
fig.add_trace(go.Scatter(x=time_column, y=bh_column, mode='lines', name='bh'))
fig.add_trace(go.Scatter(x=time_column, y=fuzzy_column, mode='lines', name='fuzzy'))
fig.add_trace(go.Scatter(x=time_column, y=fuzzy_c_column, mode='lines', name='fuzzy c'))
fig.update_layout(
    xaxis=dict(title='Time'),
    yaxis=dict(title='USD $'),
)

fig.show()
